# %%
import numpy as np
import pandas as pd

Base_path='/home/shunya/PythonProjects/cassava-leaf-disease-classification/input/cassava-leaf-disease-classification/'
Train_csv_path= Base_path + 'train.csv'

# %%
df = pd.read_csv(Train_csv_path)
print(df.shape)
df.head()
# Out:
# (21397, 2)
#          image_id  label
# 0  1000015157.jpg      0
# 1  1000201771.jpg      3
# 2   100042118.jpg      1
# 3  1000723321.jpg      1
# 4  1000812911.jpg      3

# %%
df_lbl = df['label']
df_lbl.head()
# Out:
# 0    0
# 1    3
# 2    1
# 3    1
# 4    3
# Name: label, dtype: int64

# %%
import matplotlib.pyplot as plt
df['label'].value_counts().plot(kind='bar');
plt.title('Class counts');

# %%
## disp 5 images from each class
fig = plt.figure(figsize=(25, 16))
